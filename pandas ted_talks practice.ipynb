# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
# %matplotlib inline

# %%
ted = pd.read_csv('ted_main.csv')

# %%
ted.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
ted.shape
# Out:
# (2550, 17)

# %%
ted.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
ted.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %% [markdown]
# # which talks provoke the most online discussion?

# %%
ted.sort_values('comments').tail()
# Out:
#       comments                                        description  duration  \
# 1787      2673  Our consciousness is a fundamental aspect of o...      1117
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
#
#         event   film_date  languages       main_speaker  \
# 1787  TED2014  1395100800         33     David Chalmers
# 201   TED2008  1204070400         49  Jill Bolte Taylor
# 644   TED2010  1265846400         39         Sam Harris
# 0     TED2006  1140825600         60       Ken Robinson
# 96    TED2002  1012608000         42    Richard Dawkins
#
#                                                    name  num_speaker  \
# 1787  David Chalmers: How do you explain consciousness?            1
# ...

# %%
# As we asked in our quwstion, we used "PROVOKE" word in our question, so our above analysis is not proper.
# So we will create a new column named 'comments_per_view' to make our analysis proper.

# %%
ted['comments_per_view'] = ted.comments / ted.views

# %%
ted.sort_values('comments_per_view').tail()
# Out:
#      comments                                        description  duration  \
# 954      2492  Janet Echelman found her true voice as an arti...       566
# 694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 96       6404  Richard Dawkins urges all atheists to openly s...      1750
# 803       834  David Bismark demos a new system for voting th...       422
# 744       649  Hours before New York lawmakers rejected a key...       453
#
#                      event   film_date  languages           main_speaker  \
# 954                TED2011  1299110400         35         Janet Echelman
# 694                TED2010  1265760000         32  Sharmeen Obaid-Chinoy
# 96                 TED2002  1012608000         42        Richard Dawkins
# 803         TEDGlobal 2010  1279065600         36          David Bismark
# 744  New York State Senate  1259712000          0        Diane J. Savino
#
#                                                   name  num_speaker  \
# ...

# %%
#to make our analysis more interpretable we will create a new column named 'views_per_comment'

# %%
ted['views_per_comment'] = ted.views / ted.comments

# %%
ted.sort_values('views_per_comment').head()
# Out:
#      comments                                        description  duration  \
# 744       649  Hours before New York lawmakers rejected a key...       453
# 803       834  David Bismark demos a new system for voting th...       422
# 96       6404  Richard Dawkins urges all atheists to openly s...      1750
# 694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 954      2492  Janet Echelman found her true voice as an arti...       566
#
#                      event   film_date  languages           main_speaker  \
# 744  New York State Senate  1259712000          0        Diane J. Savino
# 803         TEDGlobal 2010  1279065600         36          David Bismark
# 96                 TED2002  1012608000         42        Richard Dawkins
# 694                TED2010  1265760000         32  Sharmeen Obaid-Chinoy
# 954                TED2011  1299110400         35         Janet Echelman
#
#                                                   name  num_speaker  \
# ...

# %% [markdown]
# # Visualize the distribution of comments

# %%
ted.comments.plot()

# %%
ted[ted.comments >= 1000].shape
# Out:
# (32, 19)

# %%
ted.query('comments < 1000').comments.plot(kind = 'hist', bins = 20)
#alternative
#ted[ted.comments < 1000].comments.plot(kind = 'hist')
#ted.loc[ted.comments < 1000, 'comments'].plot(kind = 'hist')

# %%
ted.query('comments < 1000').comments.plot(kind = 'hist', bins = 20, color = 'r')
plt.title('comments distribution')
plt.xlabel('comments')
plt.legend()
plt.show()

# %% [markdown]
# # plot the number of talks that took place each year

# %%
ted.event
# Out:
# 0              TED2006
# 1              TED2006
# 2              TED2006
# 3              TED2006
# 4              TED2006
# 5              TED2006
# 6              TED2006
# 7              TED2006
# 8              TED2006
# 9              TED2006
# 10             TED2006
# 11             TED2006
# 12             TED2006
# 13             TED2006
# 14             TED2006
# 15             TED2006
# 16             TED2004
# 17             TED2006
# 18             TED2005
# 19      TEDGlobal 2005
# 20             TED2006
# 21             TED2004
# 22             TED2006
# 23             TED2006
# 24             TED2004
# 25      TEDGlobal 2005
# 26      TEDGlobal 2005
# 27             TED2004
# 28             TED2004
# 29             TED2004
#              ...
# 2520           TED2017
# 2521      TEDxStanford
# 2522           TED2017
# 2523      TEDxCrenshaw
# 2524           TED2017
# 2525        TEDxSydney
# 2526           TED2017
# 2527      TEDxStanford
# 2528       TEDxHamburg
# ...

# %%
ted.event.sample(10)
# Out:
# 1469           TED2013
# 230            TED2008
# 378            TED2003
# 1593    TEDGlobal 2013
# 878      TEDWomen 2010
# 2211           TED2016
# 1523    TEDGlobal 2013
# 2418           TED2016
# 959            TED2011
# 2451           TED2017
# Name: event, dtype: object

# %%
ted.film_date.head()
# Out:
# 0    1140825600
# 1    1140825600
# 2    1140739200
# 3    1140912000
# 4    1140566400
# Name: film_date, dtype: int64

# %%
ted['film_datetime'] = pd.to_datetime(ted.film_date, unit = 's')

# %%
ted[['event','film_datetime']].sample(5)
# Out:
#                event film_datetime
# 1520         TED2013    2013-02-27
# 1090  TEDGlobal 2011    2011-07-14
# 1860     TEDMED 2014    2014-09-18
# 1148    TEDxVictoria    2011-11-19
# 992   TEDGlobal 2011    2011-07-13

# %%
ted.dtypes
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date                      int64
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date                 int64
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# comments_per_view            float64
# views_per_comment            float64
# film_datetime         datetime64[ns]
# dtype: object

# %%
ted.film_datetime.dt.year.value_counts() #year,dayofweek, dayofyear... can be used
# Out:
# 2013    270
# 2011    270
# 2010    267
# 2012    267
# 2016    246
# 2015    239
# 2014    237
# 2009    232
# 2007    114
# 2017     98
# 2008     84
# 2005     66
# 2006     50
# 2003     33
# 2004     33
# 2002     27
# 1998      6
# 2001      5
# 1983      1
# 1991      1
# 1994      1
# 1990      1
# 1984      1
# 1972      1
# Name: film_datetime, dtype: int64

# %%
#ted.event.str.lower()
ted.film_datetime.dt.year.value_counts().plot(kind= 'bar')

# %%
ted.film_datetime.dt.year.value_counts().sort_index().plot()

# %%
ted.film_datetime.max()
# Out:
# Timestamp('2017-08-27 00:00:00')

# %% [markdown]
# # What were the "best" events in TED history to attend?

# %%
ted.event.value_counts().head()
# Out:
# TED2014    84
# TED2009    83
# TED2016    77
# TED2013    77
# TED2015    75
# Name: event, dtype: int64

# %%
ted.groupby('event').views.mean().sort_values().tail()
# Out:
# event
# TEDxNorrkoping        6569493.0
# TEDxCreativeCoast     8444981.0
# TEDxBloomington       9484259.5
# TEDxHouston          16140250.5
# TEDxPuget Sound      34309432.0
# Name: views, dtype: float64

# %%
ted.groupby('event').views.agg(['count','mean']).sort_values('mean').tail()
# Out:
#                    count        mean
# event
# TEDxNorrkoping         1   6569493.0
# TEDxCreativeCoast      1   8444981.0
# TEDxBloomington        2   9484259.5
# TEDxHouston            2  16140250.5
# TEDxPuget Sound        1  34309432.0

# %%
ted.groupby('event').views.agg(['count','mean','sum']).sort_values('sum').tail() #to make our approch better , we use 'sum'
# Out:
#                 count          mean        sum
# event
# TED2006            45  3.274345e+06  147345533
# TED2015            75  2.011017e+06  150826305
# TEDGlobal 2013     66  2.584163e+06  170554736
# TED2014            84  2.072874e+06  174121423
# TED2013            77  2.302700e+06  177307937

# %% [markdown]
# # unpack the ratings data

# %%
ted.ratings.head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
ted.ratings[0]
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %%
#To unpack data ,wtrie below code

# %%
import ast

# %%
ast.literal_eval('[1,2,3]')
# Out:
# [1, 2, 3]

# %%
ast.literal_eval(ted.ratings[0])
# Out:
# [{'count': 19645, 'id': 7, 'name': 'Funny'},
#  {'count': 4573, 'id': 1, 'name': 'Beautiful'},
#  {'count': 6073, 'id': 9, 'name': 'Ingenious'},
#  {'count': 3253, 'id': 3, 'name': 'Courageous'},
#  {'count': 387, 'id': 11, 'name': 'Longwinded'},
#  {'count': 242, 'id': 2, 'name': 'Confusing'},
#  {'count': 7346, 'id': 8, 'name': 'Informative'},
#  {'count': 10581, 'id': 22, 'name': 'Fascinating'},
#  {'count': 300, 'id': 21, 'name': 'Unconvincing'},
#  {'count': 10704, 'id': 24, 'name': 'Persuasive'},
#  {'count': 4439, 'id': 23, 'name': 'Jaw-dropping'},
#  {'count': 1174, 'id': 25, 'name': 'OK'},
#  {'count': 209, 'id': 26, 'name': 'Obnoxious'},
#  {'count': 24924, 'id': 10, 'name': 'Inspiring'}]

# %%
def str_to_list(ratings_str):
    return ast.literal_eval(ratings_str)

# %%
str_to_list(ted.ratings[0])
# Out:
# [{'count': 19645, 'id': 7, 'name': 'Funny'},
#  {'count': 4573, 'id': 1, 'name': 'Beautiful'},
#  {'count': 6073, 'id': 9, 'name': 'Ingenious'},
#  {'count': 3253, 'id': 3, 'name': 'Courageous'},
#  {'count': 387, 'id': 11, 'name': 'Longwinded'},
#  {'count': 242, 'id': 2, 'name': 'Confusing'},
#  {'count': 7346, 'id': 8, 'name': 'Informative'},
#  {'count': 10581, 'id': 22, 'name': 'Fascinating'},
#  {'count': 300, 'id': 21, 'name': 'Unconvincing'},
#  {'count': 10704, 'id': 24, 'name': 'Persuasive'},
#  {'count': 4439, 'id': 23, 'name': 'Jaw-dropping'},
#  {'count': 1174, 'id': 25, 'name': 'OK'},
#  {'count': 209, 'id': 26, 'name': 'Obnoxious'},
#  {'count': 24924, 'id': 10, 'name': 'Inspiring'}]

# %%
ted.ratings.apply(ast.literal_eval).head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
ted['ratings_list'] = ted.ratings.apply(lambda x: ast.literal_eval(x))

# %%
type(ted.ratings_list[0])
# Out:
# list

# %%
ted.ratings_list
# Out:
# 0       [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1       [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2       [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3       [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4       [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# 5       [{'id': 7, 'name': 'Funny', 'count': 1102}, {'...
# 6       [{'id': 3, 'name': 'Courageous', 'count': 477}...
# 7       [{'id': 9, 'name': 'Ingenious', 'count': 195},...
# 8       [{'id': 3, 'name': 'Courageous', 'count': 562}...
# 9       [{'id': 21, 'name': 'Unconvincing', 'count': 8...
# 10      [{'id': 3, 'name': 'Courageous', 'count': 169}...
# 11      [{'id': 1, 'name': 'Beautiful', 'count': 70}, ...
# 12      [{'id': 8, 'name': 'Informative', 'count': 188...
# 13      [{'id': 9, 'name': 'Ingenious', 'count': 1014}...
# 14      [{'id': 3, 'name': 'Courageous', 'count': 83},...
# 15      [{'id': 1, 'name': 'Beautiful', 'count': 1671}...
# ...

# %%
ted.dtypes
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date                      int64
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date                 int64
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# comments_per_view            float64
# views_per_comment            float64
# film_datetime         datetime64[ns]
# ratings_list                  object
# dtype: object

# %% [markdown]
# # Count the total number of ratings recieved by each talk

# %% [markdown]
# ####    -> new column named 'num_ratings'
# #### bonus:
# ####  1.for each talk calculate the percentage of ratings that were negative
# ####  2.for each talk, calculate the average number of ratings it recieved per day since it was published

# %%
ted.ratings_list[0]
# Out:
# [{'count': 19645, 'id': 7, 'name': 'Funny'},
#  {'count': 4573, 'id': 1, 'name': 'Beautiful'},
#  {'count': 6073, 'id': 9, 'name': 'Ingenious'},
#  {'count': 3253, 'id': 3, 'name': 'Courageous'},
#  {'count': 387, 'id': 11, 'name': 'Longwinded'},
#  {'count': 242, 'id': 2, 'name': 'Confusing'},
#  {'count': 7346, 'id': 8, 'name': 'Informative'},
#  {'count': 10581, 'id': 22, 'name': 'Fascinating'},
#  {'count': 300, 'id': 21, 'name': 'Unconvincing'},
#  {'count': 10704, 'id': 24, 'name': 'Persuasive'},
#  {'count': 4439, 'id': 23, 'name': 'Jaw-dropping'},
#  {'count': 1174, 'id': 25, 'name': 'OK'},
#  {'count': 209, 'id': 26, 'name': 'Obnoxious'},
#  {'count': 24924, 'id': 10, 'name': 'Inspiring'}]

# %%
pd.DataFrame(ted.ratings_list[0])['count'].sum()
# Out:
# 93850

# %%
def get_num_ratings(list_of_dicts):
    num = 0
    for d in list_of_dicts:
        num = num + d['count']
        return num
    #return list_of_dicts[0]['count']

# %%
get_num_ratings(ted.ratings_list[0])
# Out:
# 19645

# %%
ted['num_ratings'] = ted.ratings_list.apply(get_num_ratings)

# %%
ted.num_ratings.describe()
# Out:
# count     2550.000000
# mean       445.970980
# std       1024.884737
# min          1.000000
# 25%         97.000000
# 50%        219.000000
# 75%        449.750000
# max      21444.000000
# Name: num_ratings, dtype: float64

# %%
ted
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %% [markdown]
# # which occupations deliever the funniest TED talks on average
# #### Bonus:
# #### -> for each talk, calculate the most frequent rating
# #### -> for each talk, clean the occupation data so that there's only occupation per talk

# %% [markdown]
# ## Step 1: Count the number of funny ratings

# %%
ted.ratings_list.head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings_list, dtype: object

# %%
ted.ratings.str.contains('Funny').value_counts()
# Out:
# True    2550
# Name: ratings, dtype: int64

# %%
def get_funny_ratings(list_of_dicts):
    for d in list_of_dicts:
        if d['name'] == 'Funny':
            return d['count']

# %%
ted['funny_ratings'] = ted.ratings_list.apply(get_funny_ratings)

# %%
ted.funny_ratings.head()
# Out:
# 0    19645
# 1      544
# 2      964
# 3       59
# 4     1390
# Name: funny_ratings, dtype: int64

# %%
ted['funny_rate'] = ted.funny_ratings / ted.num_ratings

# %%
ted.sort_values('funny_rate').speaker_occupation.tail(20)
#ted.sort_values('funny_rate').speaker_occupation.head(20)
# Out:
# 1398                            Comedian
# 1103                      Data scientist
# 493     Experimental audio-visual artist
# 193                    Singer/songwriter
# 1680                         Philosopher
# 795                 Editorial cartoonist
# 2471                  Novelist, essayist
# 72                      Graphic designer
# 2530                              Artist
# 518                         Net watchdog
# 906                            Filmmaker
# 2548                 Public intellectual
# 138                    Dictionary editor
# 1967      Neuroscientist, stand-up comic
# 1665       Musician and graphic designer
# 1018                     Data researcher
# 2476                                Band
# 337                             Comedian
# 607                               Author
# 1502                     Author/educator
# Name: speaker_occupation, dtype: object

# %% [markdown]
# ## Step 3: Analyze the funny rate by occupation

# %%
ted.groupby('speaker_occupation').funny_rate.mean().sort_values().tail()
# Out:
# speaker_occupation
# Net watchdog                      16.545455
# Author/educator                   16.650913
# Band                              17.031613
# Neuroscientist, stand-up comic    22.179487
# Musician and graphic designer     29.800000
# Name: funny_rate, dtype: float64

# %%
ted.speaker_occupation.describe()
# Out:
# count       2544
# unique      1458
# top       Writer
# freq          45
# Name: speaker_occupation, dtype: object

# %% [markdown]
# ## Step 4: Focus on occupations that are well_representedin the data

# %%
occupation_counts = ted.speaker_occupation.value_counts()

# %%
top_occupations = occupation_counts[occupation_counts >= 5].index

# %%
type(top_occupations)
# Out:
# pandas.core.indexes.base.Index

# %%
ted_top_occupations = ted[ted.speaker_occupation.isin(top_occupations)]

# %%
ted_top_occupations.shape
# Out:
# (786, 24)

# %%
ted_top_occupations.groupby('speaker_occupation').funny_rate.mean().sort_values()
# Out:
# speaker_occupation
# Surgeon                                        0.015389
# Photojournalist                                0.026055
# Singer-songwriter                              0.032802
# Environmentalist, futurist                     0.033105
# Violinist                                      0.044561
# Investor and advocate for moral leadership     0.051892
# Physician                                      0.069211
# Photographer                                   0.076088
# Chemist                                        0.081560
# Astrophysicist                                 0.082180
# Social Media Theorist                          0.086489
# Paleontologist                                 0.102534
# Tech visionary                                 0.121425
# Historian                                      0.123752
# Activist                                       0.129470
# Computer scientist                             0.130957
# ...
